# %% [markdown]
# <a href="https://colab.research.google.com/github/Crocodyll1/Machine-Learning/blob/main/first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
h = 60
k = 666
print(h + k)
# Out:
# 726
