# %% [markdown]
# <a href="https://colab.research.google.com/github/Crocodyll1/Machine-Learning/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Seaborn
#
#     -Data Visulization Library

# %% [markdown]
# Importing the Library

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
